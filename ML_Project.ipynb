# %% [markdown]
# <a href="https://colab.research.google.com/github/21wh1a6633/-PPS-LAB/blob/main/ML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
calories = pd.read_csv('/content/drive/MyDrive/calories.csv')
exercise = pd.read_csv("/content/drive/MyDrive/exercise.csv")

# %%
calories.head()
exercise.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8

# %%
calories.head()
# Out:
#     User_ID  Calories
# 0  14733363     231.0
# 1  14861698      66.0
# 2  11179863      26.0
# 3  16180408      71.0
# 4  17771927      35.0

# %%
df=exercise.merge(calories,on='User_ID')

# %%
df.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
df.shape
# Out:
# (15000, 9)

# %%
#sns.countplot(x='Gender', data=df)
#plt.xlabel('Gender')
#plt.ylabel('Count')
#plt.title('Count of Gender')
#plt.show()

# %%
df['Gender'].value_counts()
# Out:
# female    7553
# male      7447
# Name: Gender, dtype: int64

# %%
#plt.hist(df['Age'],bins=20)

# %%
df.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
#sns.scatterplot(x=df['Age'],y=df['Calories'])

# %%
#sns.scatterplot(x=df['Calories'],y = df['Age'])
# Out:
# <Axes: xlabel='Calories', ylabel='Age'>

# %%
#sns.barplot(x='Age', y='Calories', data=df)
#plt.xlabel('Age')
#plt.ylabel('Calories')
#plt.title('Bar Plot of Age vs. Calories')
#plt.show()

# %%
#sns.boxplot(x='Gender', y='Height', data=df)
#plt.xlabel('Gender')
#plt.ylabel('Height')
#plt.title('Box Plot of Height by Gender')
#plt.show()

# %%
df.describe()
# Out:
#             User_ID           Age        Height        Weight      Duration  \
# count  1.500000e+04  15000.000000  15000.000000  15000.000000  15000.000000
# mean   1.497736e+07     42.789800    174.465133     74.966867     15.530600
# std    2.872851e+06     16.980264     14.258114     15.035657      8.319203
# min    1.000116e+07     20.000000    123.000000     36.000000      1.000000
# 25%    1.247419e+07     28.000000    164.000000     63.000000      8.000000
# 50%    1.499728e+07     39.000000    175.000000     74.000000     16.000000
# 75%    1.744928e+07     56.000000    185.000000     87.000000     23.000000
# max    1.999965e+07     79.000000    222.000000    132.000000     30.000000
#
#          Heart_Rate     Body_Temp      Calories
# count  15000.000000  15000.000000  15000.000000
# mean      95.518533     40.025453     89.539533
# std        9.583328      0.779230     62.456978
# min       67.000000     37.100000      1.000000
# ...

# %%
df['Gender']
# Out:
# 0          male
# 1        female
# 2          male
# 3        female
# 4        female
#           ...
# 14995    female
# 14996    female
# 14997    female
# 14998      male
# 14999      male
# Name: Gender, Length: 15000, dtype: object

# %%
df['Gender'] = df['Gender'].map({'male':1,"female":0})

# %%
df.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363       1   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698       0   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863       1   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408       0   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927       0   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
X = df.drop(['User_ID','Calories'],axis=1)
y =df['Calories']

# %%
X.shape
# Out:
# (15000, 7)

# %%
y.shape
# Out:
# (15000,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=42)

# %%
X_train.shape
# Out:
# (10050, 7)

# %%
X_test.shape
# Out:
# (4950, 7)

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import r2_score, mean_squared_error

# %%
from sklearn.metrics import r2_score, mean_squared_error

models = {
    'lr': LinearRegression(),
    'rd': Ridge(),
    'ls': Lasso(),
    'dtr': DecisionTreeRegressor(),
    'rfr': RandomForestRegressor()
}

# %%
for name, mod in models.items():
    mod.fit(X_train, y_train)
    y_pred = mod.predict(X_test)

    print(f"{name}  MSE: {mean_squared_error(y_test, y_pred)}, Score: {r2_score(y_test, y_pred)}")
# Out:
# lr  MSE: 132.91211125710095, Score: 0.9663701348612177
# rd  MSE: 132.91250867822333, Score: 0.9663700343044014
# ls  MSE: 144.05283790176733, Score: 0.9635512710942925
# dtr  MSE: 30.572727272727274, Score: 0.9922643867034979
# rfr  MSE: 9.37100911111111, Score: 0.9976289160585873

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor()
rfr.fit(X_train, y_train)
y_pred = rfr.predict(X_test)

# %%
import pickle

pickle.dump(rfr, open('rfr.pkl', 'wb'))
X_train.to_csv('X_train.csv')
